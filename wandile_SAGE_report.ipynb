# %% [markdown]
# ### REPORT [17  October 2022]

# %% [markdown]
# We were introduce to SageMath. SageMath is an open source mathematical software which is almost like python. We can use sage it when we want to find conjectures.
#
# The first proposition we did  was : What is the value of the complex numb $(1-i)^k$ for $k \geq0$.First we do the examples
# $(1-i)^2$ =$1$     $\quad$    for $k= 0$
#
# $(1-i)^1$ =$(1-i)$ $\quad$  for $k= 1$
#
# $(1-i)^2$ =$(-2i$  $\quad$    for $k= 2$
#
# $(1-i)^2$ =$-2i-2$ $\quad$    for $k= 3$
#
# $(1-i)^2$ =$-4$    $\quad$    for $k= 5$
#
# $(1-i)^2$ =$-4-4i$ $\quad$    for $k= 5$
#
# $(1-i)^2$ =$8i$    $\quad$    for $k= 6$
#
# $(1-i)^2$ =$8i+8$  $\quad$    for $k= 7$
#
# $(1-i)^2$ =$16$    $\quad$    for $k= 8$
#
# $(1-i)^2$ =$16-16i$  $\quad$    for $k= 9$
#
# $(1-i)^2$ =$-32i$    $\quad$    for $k= 10$
#
# The first conjecuture was: \
#  k is  odd: $(1-i)^k = (-2i)^\frac{k-1}{2}(1-i)$
#
#  k is  even: $(1-i)^k = (-2i)^\frac{k}{2}$
#
# This was pointed out by Mohammed. The second statement  was by Kelie and is \
# $g =(1-i)^2$\
# let $w = 1-i$ \
# $w  = \sqrt{2}(cos(\frac{-\pi}{4})+isin(\frac{-\pi}{4}))$
#
# Then from De Moiure \
# $g = w^2= \sqrt{2}(cos(\frac{-k\pi}{4})+isin(\frac{-k\pi}{4}))$
#
#
# The second proposition we did  was are fermat numbers prime, this numbers are generated by $F_n = 2^{2^n}+1$ where $n\geq0$. We did the examples as follows\
# $n=1:  2^{2^1}+1 = 5 $ which is prime\
# $n=2:  2^{2^2}+1 = 17 $ which is prime\
# $n=3:  2^{2^3}+1 = 257 $ which is prime\
# $n=4:  2^{2^4}+1 = 65537 $ which is prime\
# $n=5:  2^{2^4}+1 = 4294967297 $ which is not prime. Since the python code give a factor below
#
# This is a prove by counterexample that when $n=5$ fermat numnber produced is a not a prime number.
# The third proposition what  are there real solution of $x^k-x-1 = 0$ for $k\geq2$.
#
# $k = 2; x^2-x-1$\
# Using the quadratic equation we $\frac{b\pm \sqrt{b^2-4ac}}{2a}$
# The roots  are include the golde ration $x = \pm\frac{\sqrt{5}-2}{2}$
#
#
#
# Afternoon. We learn that Sage runs on jupiter notebook also, that it operates as a calculator  as for example
# $(2+3*4^6-45/21) = 86015/7$
#
# $4 + 2 = 6$
#
# The also in Sage there are built in functions like derative  and functions which you can assess their  source code by doing this: nameoffunction??. Some functions include functions like numerical_approx(), divmod().

# %%
import math as ma
numb = int(input("Enter an integer:"))
first_num = 2**numb  # this is the power number in the fermat formulae
fermat_numb =  2**first_num +1 
print(fermat_numb)


for i in range(2,fermat_numb+1):
    if fermat_numb%i==0 and i!=fermat_numb :
        print("The factors of {} is given by {} ".format(fermat_numb,i))
# Out:
# Enter an integer:3
# 257
