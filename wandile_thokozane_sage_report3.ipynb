# %% [markdown]
# ### Report 3 ( 19 OCTEBER 2022)
#
#
# The problem in class was to find if possible can we express any number from 1 to 100 using two numbers. Lets take for instance we have two coins or two numbers can we express any number from 1 to 100 using those numbers.
#
# To look for a general expression  we started with  a=2 and b= 3, and the 1,2,3,4 are the numbers that cannot be expressed as a linear combination of a nd b or ($a*y + b*y$)a and $x,y \in \mathbb{N} $.
#
# With the implication of a python code,we can check any numbers now and see which  numbers are possible  when
#
# a =2 ,b=3
#
#
# a =2 ,b=6
#
#
# a =3 ,b=5
#
# a =3 ,b=4
#
# The function below checks the number  which are a linear combination of a and b from 1 to 100

# %%
def frob(n):
    numb =  1
    a =  int(input("Enter the number a: "))
    b =  int(input("Enter the number b: "))

    trial_dict = {}

    while numb<= n:
        List = []
        for x in range(1,101):
            for y in range(1,101):
                if (a*x + b*y)==numb :
                    #print('The x value  is',x,'The y value  is',y,"for " ,n)
                    store = (x,y)
                    List.append(store)
                    #print("For {} the combination is {}".format(n,List))
                    trial_dict[str(numb)] = List

        numb += 1
    return print(trial_dict)
frob(100)
# Out:
# Enter the number a: 2
# Enter the number b: 3
# ...

# %%
4+4
